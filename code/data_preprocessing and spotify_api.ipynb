# %%
# !pip install spotipy
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
#Establishing Connection to the api 
client_credentials_manager = SpotifyClientCredentials(client_id="5c09ba8609314038b00c59c34bad2429",client_secret="037e678b2b2e43f6ab2b50ccb2aa8ac3")

# %%
#Creating Variable For Client Creditinal Manager
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/5iwkYfnHAGMEFLiHFFGnP4"

# %%
playlists = sp.user_playlists('spotify')

# %%
playlist_URI=playlist_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_tracks(playlist_URI)   # Playlist_tracks is a function available in spotipy

# %%
data['items']
# Out:
# [{'added_at': '2025-04-25T15:02:33Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/topsify'},
#    'href': 'https://api.spotify.com/v1/users/topsify',
#    'id': 'topsify',
#    'type': 'user',
#    'uri': 'spotify:user:topsify'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
# ...

# %% [markdown]
# ### 1.Album Info

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6xomx5ekO7qHDvDh57rZ5S'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Ordinary'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-02-07'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6xomx5ekO7qHDvDh57rZ5S'

# %%
album_list=[]
for row in data['items']:
    album_id= row['track']['album']['id']
    album_name= row['track']['album']['name']
    album_release_date= row['track']['album']['release_date']
    album_total_tracks= row['track']['album']['total_tracks']
    album_url= row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                    'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6xomx5ekO7qHDvDh57rZ5S',
#   'name': 'Ordinary',
#   'release_date': '2025-02-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6xomx5ekO7qHDvDh57rZ5S'},
#  {'album_id': '7kFyd5oyJdVX2pIi6P4iHE',
#   'name': 'rosie',
#   'release_date': '2024-12-06',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/7kFyd5oyJdVX2pIi6P4iHE'},
#  {'album_id': '37HwcDtLqY2WXN7NArODvI',
#   'name': 'Azizam',
#   'release_date': '2025-04-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/37HwcDtLqY2WXN7NArODvI'},
#  {'album_id': '2MHUaRi9OCyTN02SoyRRBJ',
#   'name': 'MAYHEM',
#   'release_date': '2025-03-07',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/2MHUaRi9OCyTN02SoyRRBJ'},
#  {'album_id': '03guxdOi12XJbnvxvxbpwG',
#   'name': 'Submarine',
#   'release_date': '2024-05-31',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/03guxdOi12XJbnvxvxbpwG'},
#  {'album_id': '38PKSUSFXnO4mbUhLC4ELZ',
# ...

# %% [markdown]
# ### 2 artist info

# %%
data['items']
# Out:
# [{'added_at': '2025-04-25T15:02:33Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/topsify'},
#    'href': 'https://api.spotify.com/v1/users/topsify',
#    'id': 'topsify',
#    'type': 'user',
#    'uri': 'spotify:user:topsify'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
# ...

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#   'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#   'id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'name': 'Ed Sheeran',
#   'type': 'artist',
#   'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}]

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],
                            'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
#   'artist_name': 'Alex Warren',
#   'external_url': 'https://api.spotify.com/v1/artists/0fTSzq9jAh4c36UVb4V7CB'},
#  {'artist_id': '3eVa5w3URK5duf6eyVDbu9',
#   'artist_name': 'ROSÉ',
#   'external_url': 'https://api.spotify.com/v1/artists/3eVa5w3URK5duf6eyVDbu9'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms'},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C'},
#  {'artist_id': '2sSGPbdZJkaSE2AbcGOACx',
# ...

# %% [markdown]
# ### 3.song info

# %%
song_list=[]
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms'] 
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                   'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                   'artist_id':artist_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6qqrTXSdwiJaq8SO0X2lSe',
#   'song_name': 'Ordinary',
#   'duration_ms': 186964,
#   'url': 'https://open.spotify.com/track/6qqrTXSdwiJaq8SO0X2lSe',
#   'popularity': 96,
#   'song_added': '2025-04-25T15:02:33Z',
#   'album_id': '6xomx5ekO7qHDvDh57rZ5S',
#   'artist_id': '0fTSzq9jAh4c36UVb4V7CB'},
#  {'song_id': '4wJ5Qq0jBN4ajy7ouZIV1c',
#   'song_name': 'APT.',
#   'duration_ms': 169917,
#   'url': 'https://open.spotify.com/track/4wJ5Qq0jBN4ajy7ouZIV1c',
#   'popularity': 91,
#   'song_added': '2025-04-25T15:02:33Z',
#   'album_id': '7kFyd5oyJdVX2pIi6P4iHE',
#   'artist_id': '3eVa5w3URK5duf6eyVDbu9'},
#  {'song_id': '0GRc3eGTg8HBdWLRGYgqIc',
#   'song_name': 'Azizam',
#   'duration_ms': 162029,
#   'url': 'https://open.spotify.com/track/0GRc3eGTg8HBdWLRGYgqIc',
#   'popularity': 89,
#   'song_added': '2025-04-25T15:02:33Z',
#   'album_id': '37HwcDtLqY2WXN7NArODvI',
#   'artist_id': '6eUKZXaKkcviH0Ku9w2n3V'},
#  {'song_id': '7so0lgd0zP2Sbgs2d7a1SZ',
# ...

# %% [markdown]
# ### conversion of dict  to dataframe using pandas

# %% [markdown]
# ### 1.album_df

# %%
import pandas as pd
album_df= pd.DataFrame.from_dict(album_list) #### album_df
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df.head()
# Out:
#                  album_id       name release_date  total_tracks  \
# 0  6xomx5ekO7qHDvDh57rZ5S   Ordinary   2025-02-07             1
# 1  7kFyd5oyJdVX2pIi6P4iHE      rosie   2024-12-06            12
# 2  37HwcDtLqY2WXN7NArODvI     Azizam   2025-04-04             1
# 3  2MHUaRi9OCyTN02SoyRRBJ     MAYHEM   2025-03-07            14
# 4  03guxdOi12XJbnvxvxbpwG  Submarine   2024-05-31            14
#
#                                                  url
# 0  https://open.spotify.com/album/6xomx5ekO7qHDvD...
# 1  https://open.spotify.com/album/7kFyd5oyJdVX2pI...
# 2  https://open.spotify.com/album/37HwcDtLqY2WXN7...
# 3  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 4  https://open.spotify.com/album/03guxdOi12XJbnv...

# %% [markdown]
# ### 2.artist_df

# %%
artist_df= pd.DataFrame.from_dict(artist_list) #### artist_df
artist_df = artist_df.drop_duplicates(subset=['artist_id'])
artist_df.head()
# Out:
#                 artist_id  artist_name  \
# 0  0fTSzq9jAh4c36UVb4V7CB  Alex Warren
# 1  3eVa5w3URK5duf6eyVDbu9         ROSÉ
# 2  0du5cEVh5yTK9QJze8zA0C   Bruno Mars
# 3  6eUKZXaKkcviH0Ku9w2n3V   Ed Sheeran
# 4  1HY2Jd0NmPuamShAr6KMms    Lady Gaga
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 1  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 2  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 3  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 4  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...

# %% [markdown]
# ###  3.song_df

# %%
song_df= pd.DataFrame.from_dict(song_list) #### song_df
song_df.head() ## since songs are unique so no need to drop duplicates
# Out:
#                   song_id         song_name  duration_ms  \
# 0  6qqrTXSdwiJaq8SO0X2lSe          Ordinary       186964
# 1  4wJ5Qq0jBN4ajy7ouZIV1c              APT.       169917
# 2  0GRc3eGTg8HBdWLRGYgqIc            Azizam       162029
# 3  7so0lgd0zP2Sbgs2d7a1SZ  Die With A Smile       251667
# 4  3siwsiaEoU4Kuuc9WKMUy5    No One Noticed       236906
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6qqrTXSdwiJaq8S...          96
# 1  https://open.spotify.com/track/4wJ5Qq0jBN4ajy7...          91
# 2  https://open.spotify.com/track/0GRc3eGTg8HBdWL...          89
# 3  https://open.spotify.com/track/7so0lgd0zP2Sbgs...          91
# 4  https://open.spotify.com/track/3siwsiaEoU4Kuuc...          93
#
#              song_added                album_id               artist_id
# 0  2025-04-25T15:02:33Z  6xomx5ekO7qHDvDh57rZ5S  0fTSzq9jAh4c36UVb4V7CB
# 1  2025-04-25T15:02:33Z  7kFyd5oyJdVX2pIi6P4iHE  3eVa5w3URK5duf6eyVDbu9
# ...

# %% [markdown]
# ### proper structuring

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      59 non-null     object
#  1   name          59 non-null     object
#  2   release_date  59 non-null     datetime64[ns]
#  3   total_tracks  59 non-null     int64
#  4   url           59 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.8+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      60 non-null     object
#  1   song_name    60 non-null     object
#  2   duration_ms  60 non-null     int64
#  3   url          60 non-null     object
#  4   popularity   60 non-null     int64
#  5   song_added   60 non-null     datetime64[ns, UTC]
#  6   album_id     60 non-null     object
#  7   artist_id    60 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.9+ KB

# %% [markdown]
# ## Final Data

# %%
album_df.head()
# Out:
#                  album_id       name release_date  total_tracks  \
# 0  6xomx5ekO7qHDvDh57rZ5S   Ordinary   2025-02-07             1
# 1  7kFyd5oyJdVX2pIi6P4iHE      rosie   2024-12-06            12
# 2  37HwcDtLqY2WXN7NArODvI     Azizam   2025-04-04             1
# 3  2MHUaRi9OCyTN02SoyRRBJ     MAYHEM   2025-03-07            14
# 4  03guxdOi12XJbnvxvxbpwG  Submarine   2024-05-31            14
#
#                                                  url
# 0  https://open.spotify.com/album/6xomx5ekO7qHDvD...
# 1  https://open.spotify.com/album/7kFyd5oyJdVX2pI...
# 2  https://open.spotify.com/album/37HwcDtLqY2WXN7...
# 3  https://open.spotify.com/album/2MHUaRi9OCyTN02...
# 4  https://open.spotify.com/album/03guxdOi12XJbnv...

# %%
artist_df.head()
# Out:
#                 artist_id  artist_name  \
# 0  0fTSzq9jAh4c36UVb4V7CB  Alex Warren
# 1  3eVa5w3URK5duf6eyVDbu9         ROSÉ
# 2  0du5cEVh5yTK9QJze8zA0C   Bruno Mars
# 3  6eUKZXaKkcviH0Ku9w2n3V   Ed Sheeran
# 4  1HY2Jd0NmPuamShAr6KMms    Lady Gaga
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0fTSzq9jAh4...
# 1  https://api.spotify.com/v1/artists/3eVa5w3URK5...
# 2  https://api.spotify.com/v1/artists/0du5cEVh5yT...
# 3  https://api.spotify.com/v1/artists/6eUKZXaKkcv...
# 4  https://api.spotify.com/v1/artists/1HY2Jd0NmPu...

# %%
song_df.head()
# Out:
#                   song_id         song_name  duration_ms  \
# 0  6qqrTXSdwiJaq8SO0X2lSe          Ordinary       186964
# 1  4wJ5Qq0jBN4ajy7ouZIV1c              APT.       169917
# 2  0GRc3eGTg8HBdWLRGYgqIc            Azizam       162029
# 3  7so0lgd0zP2Sbgs2d7a1SZ  Die With A Smile       251667
# 4  3siwsiaEoU4Kuuc9WKMUy5    No One Noticed       236906
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6qqrTXSdwiJaq8S...          96
# 1  https://open.spotify.com/track/4wJ5Qq0jBN4ajy7...          91
# 2  https://open.spotify.com/track/0GRc3eGTg8HBdWL...          89
# 3  https://open.spotify.com/track/7so0lgd0zP2Sbgs...          91
# 4  https://open.spotify.com/track/3siwsiaEoU4Kuuc...          93
#
#                  song_added                album_id               artist_id
# 0 2025-04-25 15:02:33+00:00  6xomx5ekO7qHDvDh57rZ5S  0fTSzq9jAh4c36UVb4V7CB
# 1 2025-04-25 15:02:33+00:00  7kFyd5oyJdVX2pIi6P4iHE  3eVa5w3URK5duf6eyVDbu9
# ...
